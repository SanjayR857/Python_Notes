# %% [markdown]
# ### 📘 Python `math` Module Functions Summary
#
# | Sr.No | Function               | Description                                                                                   |
# |-------|------------------------|-----------------------------------------------------------------------------------------------|
# | 1     | `math.ceil(x)`         | Returns the smallest integer ≥ x                                                              |
# | 2     | `math.comb(n, k)`      | Number of combinations: choosing k items from n without repetition or order                  |
# | 3     | `math.copysign(x, y)`  | Returns float with magnitude of x and sign of y                                               |
# | 4     | `math.cmp(x, y)`       | Compares two values (deprecated in Python 3)                                                  |
# | 5     | `math.fabs(x)`         | Absolute value of x (returns float)                                                           |
# | 6     | `math.factorial(n)`    | Factorial of n                                                                                 |
# | 7     | `math.floor(x)`        | Returns the largest integer ≤ x                                                               |
# | 8     | `math.fmod(x, y)`      | Accurate modulo operation                                                                     |
# | 9     | `math.frexp(x)`        | Returns mantissa and exponent as tuple `(m, e)` such that `x = m * 2**e`                     |
# | 10    | `math.fsum(iterable)`  | Precise floating-point sum of iterable                                                        |
# | 11    | `math.gcd(*integers)`  | Greatest common divisor of given integers                                                     |
# | 12    | `math.isclose(a, b)`   | Checks if two values are approximately equal                                                  |
# | 13    | `math.isfinite(x)`     | Checks if x is a finite number                                                                |
# | 14    | `math.isinf(x)`        | Checks if x is infinite                                                                       |
# | 15    | `math.isnan(x)`        | Checks if x is NaN (Not a Number)                                                             |
# | 16    | `math.isqrt(n)`        | Integer square root of n                                                                      |
# | 17    | `math.lcm(*integers)`  | Least common multiple of given integers                                                       |
# | 18    | `math.ldexp(x, i)`     | Returns `x * (2**i)` — inverse of `frexp()`                                                   |
# | 19    | `math.modf(x)`         | Returns fractional and integer parts as tuple `(frac, int)`                                  |
# | 20    | `math.nextafter(x, y)` | Next float after x towards y                                                                  |
# | 21    | `math.perm(n, k)`      | Number of permutations: choosing k items from n with order                                   |
# | 22    | `math.prod(iterable)`  | Product of all items in iterable                                                              |
# | 23    | `math.remainder(x, y)` | IEEE-style remainder: `x - n*y`, where n is closest integer to `x/y`                         |
# | 24    | `math.trunc(x)`        | Truncates fractional part of x                                                                |
# | 25    | `math.ulp(x)`          | Returns the unit in the last place (least significant bit) of float x                        |

# %% [markdown]
# ## 🧮 Python Math & Random Module Reference
#
# ### 🔋 Power and Logarithmic Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.cbrt(x)`     | Cube root of x                                                              |
# | 2     | `math.exp(x)`      | Exponential of x: eˣ                                                        |
# | 3     | `math.exp2(x)`     | 2 raised to the power x                                                    |
# | 4     | `math.expm1(x)`    | eˣ − 1, accurate for small x                                               |
# | 5     | `math.log(x)`      | Natural logarithm of x (base e)                                            |
# | 6     | `math.log1p(x)`    | Natural log of 1+x, accurate near zero                                     |
# | 7     | `math.log2(x)`     | Base-2 logarithm of x                                                       |
# | 8     | `math.log10(x)`    | Base-10 logarithm of x                                                      |
# | 9     | `math.pow(x, y)`   | x raised to the power y                                                    |
# | 10    | `math.sqrt(x)`     | Square root of x                                                           |
#
# ---
#
# ### 📐 Trigonometric Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.acos(x)`     | Arc cosine of x (radians)                                                  |
# | 2     | `math.asin(x)`     | Arc sine of x (radians)                                                    |
# | 3     | `math.atan(x)`     | Arc tangent of x (radians)                                                 |
# | 4     | `math.atan2(y, x)` | Arc tangent of y/x (radians)                                               |
# | 5     | `math.cos(x)`      | Cosine of x (radians)                                                      |
# | 6     | `math.sin(x)`      | Sine of x (radians)                                                        |
# | 7     | `math.tan(x)`      | Tangent of x (radians)                                                     |
# | 8     | `math.hypot(x, y)` | Euclidean norm: √(x² + y²)                                                 |
#
# ---
#
# ### 🔄 Angular Conversion Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.degrees(x)`  | Converts radians to degrees                                                |
# | 2     | `math.radians(x)`  | Converts degrees to radians                                                |
#
# ---
#
# ### 🔢 Mathematical Constants
#
# | Sr.No | Constant           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.pi`          | π ≈ 3.14159                                                                 |
# | 2     | `math.e`           | e ≈ 2.71828                                                                 |
# | 3     | `math.tau`         | τ = 2π                                                                      |
# | 4     | `math.inf`         | Positive infinity (`-math.inf` for negative)                               |
# | 5     | `math.nan`         | Not a Number (NaN)                                                          |
#
# ---
#
# ### 📈 Hyperbolic Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.acosh(x)`    | Inverse hyperbolic cosine                                                  |
# | 2     | `math.asinh(x)`    | Inverse hyperbolic sine                                                    |
# | 3     | `math.atanh(x)`    | Inverse hyperbolic tangent                                                 |
# | 4     | `math.cosh(x)`     | Hyperbolic cosine                                                          |
# | 5     | `math.sinh(x)`     | Hyperbolic sine                                                            |
# | 6     | `math.tanh(x)`     | Hyperbolic tangent                                                         |
#
# ---
#
# ### 🎯 Special Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `math.erf(x)`      | Gauss error function                                                        |
# | 2     | `math.erfc(x)`     | Complementary error function: `1 - erf(x)`                                 |
# | 3     | `math.gamma(x)`    | Gamma function (generalized factorial)                                     |
# | 4     | `math.lgamma(x)`   | Natural log of absolute gamma function                                     |
#
# ---
#
# ### 🎲 Random Module Functions
#
# | Sr.No | Function                   | Description                                                             |
# |-------|----------------------------|-------------------------------------------------------------------------|
# | 1     | `random.choice(seq)`       | Random item from list, tuple, or string                                |
# | 2     | `random.randrange(start, stop[, step])` | Random element from range(start, stop, step)           |
# | 3     | `random.random()`          | Random float in [0.0, 1.0)                                              |
# | 4     | `random.seed([x])`         | Sets seed for random number generator                                  |
# | 5     | `random.shuffle(seq)`      | Shuffles sequence in place                                             |
# | 6     | `random.uniform(a, b)`     | Random float in [a, b)                                                  |
#
# ---
#
# ### ⚙️ Built-in Mathematical Functions
#
# | Sr.No | Function           | Description                                                                 |
# |-------|--------------------|-----------------------------------------------------------------------------|
# | 1     | `abs(x)`           | Absolute value of x                                                         |
# | 2     | `max(iterable)`    | Largest value in iterable or among arguments                               |
# | 3     | `min(iterable)`    | Smallest value in iterable or among arguments                              |
# | 4     | `pow(x, y)`        | x raised to power y (same as `x**y`)                                       |
# | 5     | `round(x[, n])`    | Rounds x to n decimal places                                                |
# | 6     | `sum(iterable[, start])` | Sum of iterable, optionally starting from `start`                    |
